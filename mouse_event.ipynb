# %%
import numpy as np
import cv2 as cv

# %%
events = [i for i in dir(cv)  if 'EVENT' in i]
print(events)
# Out:
# ['EVENT_FLAG_ALTKEY', 'EVENT_FLAG_CTRLKEY', 'EVENT_FLAG_LBUTTON', 'EVENT_FLAG_MBUTTON', 'EVENT_FLAG_RBUTTON', 'EVENT_FLAG_SHIFTKEY', 'EVENT_LBUTTONDBLCLK', 'EVENT_LBUTTONDOWN', 'EVENT_LBUTTONUP', 'EVENT_MBUTTONDBLCLK', 'EVENT_MBUTTONDOWN', 'EVENT_MBUTTONUP', 'EVENT_MOUSEHWHEEL', 'EVENT_MOUSEMOVE', 'EVENT_MOUSEWHEEL', 'EVENT_RBUTTONDBLCLK', 'EVENT_RBUTTONDOWN', 'EVENT_RBUTTONUP']

# %%
def click_event(event, x,y,flags,param):
    if event == cv.EVENT_LBUTTONDOWN:
        print(x,', ',y)
        strXY = f'{x} , {y}'
        cv.putText(img,strXY,(x,y),cv.FONT_HERSHEY_SIMPLEX,1,(255,255,0),2)
        cv.imshow('Image',img)
    if event == cv.EVENT_RBUTTONDOWN:
        blue = img[y,x,0]
        green = img[y,x,1]
        red = img[y,x,2]
        strBGR = f'{blue} , {green}, {red}'
        cv.putText(img,strBGR,(x,y),cv.FONT_HERSHEY_SIMPLEX,1,(0,255,230),2)
        cv.imshow('Image',img)
cap = cv.VideoCapture('car.mp4')
pause = False
if cap.isOpened():
    while True:
        ret,img = cap.read()
        if not ret:
            break

        cv.imshow('Image',img)
        cv.setMouseCallback('Image',click_event)
        key = cv.waitKey() & 0xFF
        if key == 32:
            pause = not pause
        if cv.waitKey(20) & 0xFF == 27:
            break

cap.release
cv.destroyAllWindows()
# Out:
# 50 ,  170
# 156 ,  164
# 191 ,  208
# 404 ,  213
# 265 ,  199
# 114 ,  189
# 172 ,  211
# 485 ,  231
# 587 ,  183
# 631 ,  272

# %%
img = cv.imread('Sample/family.jpg')
cv.imshow('Image',img)
cv.setMouseCallback('Image',click_event)

cv.waitKey()
cv.destroyAllWindows()
# Out:
# 335 ,  71
# 321 ,  47
# 240 ,  37
# 215 ,  40
# 154 ,  41
# 73 ,  38
# 54 ,  27
# 32 ,  23
# 16 ,  23
# 7 ,  48
# 10 ,  103
# 7 ,  115
# 0 ,  141
# 1 ,  158
# 1 ,  192
# 4 ,  214
# 4 ,  238
# 2 ,  259
# 0 ,  274
# 3 ,  294
# 3 ,  317
# 8 ,  328
# 11 ,  352
# 15 ,  382
# 22 ,  446
# 6 ,  501
# 5 ,  517
# 6 ,  528
# 7 ,  536
# 12 ,  562
# 8 ,  599
# 8 ,  639
# 10 ,  673
# 12 ,  693
# 14 ,  715
# 16 ,  738
# 13 ,  756
# 10 ,  775
# 10 ,  791
# 10 ,  807
# 10 ,  817
# 9 ,  829
# 4 ,  867
# 4 ,  888
# 11 ,  908
# 4 ,  920
# 3 ,  920
# 1230 ,  79
# 1050 ,  88
# 992 ,  65
# 843 ,  69
# 781 ,  69
# 713 ,  69
# 663 ,  67
# 346 ,  173
# 523 ,  165
# 692 ,  163
# 865 ,  159

# %%
def mouse_event(event,x,y,flags,param):
    
    if event == cv.EVENT_LBUTTONDOWN:
        cv.circle(img,(x,y),3,(0,0,255),-1)
        points.append((x,y))
        if len(points) >= 2:
            cv.arrowedLine(img,points[-2],points[-1],(255,0,0),8)
        cv.imshow('Image',img)


        
        



points = []
img = np.zeros((512,512,3),dtype=np.uint8)
cv.imshow('Image',img)
cv.setMouseCallback('Image',mouse_event)
cv.waitKey()
cv.destroyAllWindows()

# %%
import cv2 as cv
import numpy as np

# %%
def mouse_click(event, x,y,flags,param):
    if event == cv.EVENT_LBUTTONDOWN:
        blue = img[x,y,0]
        green = img[x,y,1]
        red = img[x,y,2]

        cv.circle(img,(x,y),3,(0,0,255),-1)
        mycolor = np.zeros_like(img,dtype=np.uint8)
        mycolor[:] = [blue,green,red]

        cv.imshow('color',mycolor)








img= cv.imread('Sample/family.jpg')
cv.imshow('Image',img)
cv.setMouseCallback('Image',mouse_click)
cv.waitKey()
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 3, in mouse_click(event, x, y, flags, param)
#       1 def mouse_click(event, x,y,flags,param):
#       2     if event == cv.EVENT_LBUTTONDOWN:
# ----> 3         blue = img[x,y,0]
#       4         green = img[x,y,1]
#       5         red = img[x,y,2]
#
# IndexError: index 995 is out of bounds for axis 0 with size 960
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 3, in mouse_click(event, x, y, flags, param)
#       1 def mouse_click(event, x,y,flags,param):
#       2     if event == cv.EVENT_LBUTTONDOWN:
# ----> 3         blue = img[x,y,0]
#       4         green = img[x,y,1]
#       5         red = img[x,y,2]
#
# IndexError: index 995 is out of bounds for axis 0 with size 960

# %%
# Out:
# array([[207, 208, 210, ...,  61,  60,  59],
#        [210, 209, 209, ...,  57,  59,  60],
#        [211, 209, 207, ...,  57,  60,  64],
#        ...,
#        [181, 186, 184, ..., 135, 129, 128],
#        [178, 179, 169, ..., 131, 130, 134],
#        [180, 177, 163, ..., 130, 134, 141]],
#       shape=(960, 1280), dtype=uint8)
